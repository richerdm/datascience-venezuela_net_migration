# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Mini Project - Richerd Marques</p><br>

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold"><br>
#
# Step 1: Select a database
# </p>

# %% [markdown]
# The database selected was World Development Indicators Dataset

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold"><br>
#
# Step 2: Explore the World Development Indicators Dataset
# </p>

# %%
import pandas as pd
import sqlite3

# %%
country = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/Country.csv', sep=',')
print(type(country))
country.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   CountryCode    ShortName    TableName  \
# 0         AFG  Afghanistan  Afghanistan
# 1         ALB      Albania      Albania
# 2         DZA      Algeria      Algeria
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1                                                NaN
# 2                                                NaN
#
#                        Region          IncomeGroup Wb2Code  \
# 0                  South Asia           Low income      AF
# 1       Europe & Central Asia  Upper middle income      AL
# 2  Middle East & North Africa  Upper middle income      DZ
#
# ...

# %%
is_Venezuela = country['ShortName'].str.contains('Venezuela')

# %%
country[is_Venezuela]
# Out:
#     CountryCode  ShortName      TableName                            LongName  \
# 239         VEN  Venezuela  Venezuela, RB  República Bolivariana de Venezuela
#
#     Alpha2Code               CurrencyUnit SpecialNotes  \
# 239         VE  Venezuelan bolivar fuerte          NaN
#
#                         Region           IncomeGroup Wb2Code  \
# 239  Latin America & Caribbean  High income: nonOECD      VE
#
#                ...                 GovernmentAccountingConcept  \
# 239            ...             Consolidated central government
#
#                  ImfDataDisseminationStandard LatestPopulationCensus  \
# 239  General Data Dissemination System (GDDS)                   2011
#
#                               LatestHouseholdSurvey  \
# 239  Multiple Indicator Cluster Survey (MICS), 2000
#
#     SourceOfMostRecentIncomeAndExpenditureData VitalRegistrationComplete  \
# 239    Integrated household survey (IHS), 2012                       Yes
#
# ...

# %%
country_notes = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/CountryNotes.csv', sep=',')
print(type(country_notes))
country_notes.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...
# 1               Sources: UN Energy Statistics (2014)
# 2               Sources: UN Energy Statistics (2014)

# %%
is_Venezuela_cn = country_notes['Countrycode'].str.contains('VEN')
country_notes[is_Venezuela_cn].Description
# Out:
# 4661    Sources: World Energy Statistics and Balances,...
# 4662    Sources: World Energy Statistics and Balances,...
# 4663    Sources: World Energy Statistics and Balances,...
# 4664    Non FSI Reporter: Data for this indicator coll...
# 4665    Non FSI Reporter: Data for this indicator coll...
# 4666                    Based on official exchange rates.
# 4667    On 25 August 1999, the Constituent Assembly el...
# 4668    Data sources : United Nations World Population...
# 4669    Estimates are derived from data on foreign-bor...
# 4670    Data source : United Nations World Population ...
# 4671    Data source : United Nations World Population ...
# 4672    Data sources : United Nations World Population...
# 4673    Data sources : United Nations World Population...
# 4674    Data sources : United Nations World Population...
# 4675        Derived using male and female life expectancy
# 4676    Data sources : United Nations World Population...
# ...

# %%
is_Venezuela_cn1 = country_notes['Seriescode'].str.contains('EG.EGY.PRIM.PP.KD')
country_notes[is_Venezuela_cn1]
# Out:
#      Countrycode         Seriescode  \
# 0            ABW  EG.EGY.PRIM.PP.KD
# 22           AFG  EG.EGY.PRIM.PP.KD
# 61           AGO  EG.EGY.PRIM.PP.KD
# 87           ALB  EG.EGY.PRIM.PP.KD
# 106          ARE  EG.EGY.PRIM.PP.KD
# 123          ARG  EG.EGY.PRIM.PP.KD
# 235          ARM  EG.EGY.PRIM.PP.KD
# 256          ATG  EG.EGY.PRIM.PP.KD
# 271          AUS  EG.EGY.PRIM.PP.KD
# 304          AUT  EG.EGY.PRIM.PP.KD
# 346          AZE  EG.EGY.PRIM.PP.KD
# 378          BDI  EG.EGY.PRIM.PP.KD
# 403          BEL  EG.EGY.PRIM.PP.KD
# 455          BEN  EG.EGY.PRIM.PP.KD
# 481          BFA  EG.EGY.PRIM.PP.KD
# 497          BGD  EG.EGY.PRIM.PP.KD
# 514          BGR  EG.EGY.PRIM.PP.KD
# 554          BHR  EG.EGY.PRIM.PP.KD
# 571          BHS  EG.EGY.PRIM.PP.KD
# 588          BIH  EG.EGY.PRIM.PP.KD
# 605          BLR  EG.EGY.PRIM.PP.KD
# 622          BLZ  EG.EGY.PRIM.PP.KD
# 637          BMU  EG.EGY.PRIM.PP.KD
# 650          BOL  EG.EGY.PRIM.PP.KD
# 678          BRA  EG.EGY.PRIM.PP.KD
# ...

# %%
footnotes = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/Footnotes.csv', sep=',')
print(type(footnotes))
footnotes.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Countrycode      Seriescode    Year    Description
# 0         ABW  AG.LND.FRST.K2  YR1990  Not specified
# 1         ABW  AG.LND.FRST.K2  YR2000  Not specified
# 2         ABW  AG.LND.FRST.K2  YR2005  Not specified

# %%
indicators = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/Indicators.csv', sep=',')
print(type(indicators))
indicators.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                CountryName CountryCode  \
# 0               Arab World         ARB
# 1               Arab World         ARB
# 2               Arab World         ARB
# 3               Arab World         ARB
# 4               Arab World         ARB
# 5               Arab World         ARB
# 6               Arab World         ARB
# 7               Arab World         ARB
# 8               Arab World         ARB
# 9               Arab World         ARB
# 10              Arab World         ARB
# 11              Arab World         ARB
# 12              Arab World         ARB
# 13              Arab World         ARB
# 14              Arab World         ARB
# 15              Arab World         ARB
# 16              Arab World         ARB
# 17              Arab World         ARB
# 18              Arab World         ARB
# 19              Arab World         ARB
# 20              Arab World         ARB
# 21              Arab World         ARB
# ...

# %%
indicators_ven = indicators['CountryCode'].str.contains('VEN')
indicators[indicators_ven]
# Out:
#            CountryName CountryCode  \
# 22633    Venezuela, RB         VEN
# 22634    Venezuela, RB         VEN
# 22635    Venezuela, RB         VEN
# 22636    Venezuela, RB         VEN
# 22637    Venezuela, RB         VEN
# 22638    Venezuela, RB         VEN
# 22639    Venezuela, RB         VEN
# 22640    Venezuela, RB         VEN
# 22641    Venezuela, RB         VEN
# 22642    Venezuela, RB         VEN
# 22643    Venezuela, RB         VEN
# 22644    Venezuela, RB         VEN
# 22645    Venezuela, RB         VEN
# 22646    Venezuela, RB         VEN
# 22647    Venezuela, RB         VEN
# 22648    Venezuela, RB         VEN
# 22649    Venezuela, RB         VEN
# 22650    Venezuela, RB         VEN
# 22651    Venezuela, RB         VEN
# 22652    Venezuela, RB         VEN
# 22653    Venezuela, RB         VEN
# 22654    Venezuela, RB         VEN
# 22655    Venezuela, RB         VEN
# 22656    Venezuela, RB         VEN
# 22657    Venezuela, RB         VEN
# ...

# %%
indicators_count = indicators[['IndicatorName']].groupby('IndicatorName').count()
indicators_count
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
series = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/Series.csv', sep=',')
print(type(series))
series.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               SeriesCode                                              Topic  \
# 0         BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1   BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2      BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 3      BM.KLT.DINV.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 4         BN.TRF.KOGT.CD  Economic Policy & Debt: Balance of payments: C...
# 5         BN.KAC.EOMS.CD  Economic Policy & Debt: Balance of payments: C...
# 6         BN.FIN.TOTL.CD  Economic Policy & Debt: Balance of payments: C...
# 7      BX.PEF.TOTL.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 8         BN.KLT.PTXL.CD  Economic Policy & Debt: Balance of payments: C...
# 9      BX.KLT.DREM.CD.DT  Economic Policy & Debt: Balance of payments: C...
# 10        BN.RES.INCL.CD  Economic Policy & Debt: Balance of payments: C...
# ...

# %%
series_notes = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/SeriesNotes.csv', sep=',')
print(type(series_notes))
series_notes.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            Seriescode    Year  \
# 0         SP.ADO.TFRT  YR1960
# 1      SP.DYN.AMRT.FE  YR1960
# 2      SP.DYN.AMRT.MA  YR1960
# 3   SP.DYN.TO65.FE.ZS  YR1960
# 4   SP.DYN.TO65.MA.ZS  YR1960
# 5   SP.DYN.TO65.MA.ZS  YR1961
# 6   SP.DYN.TO65.FE.ZS  YR1961
# 7      SP.DYN.AMRT.MA  YR1961
# 8      SP.DYN.AMRT.FE  YR1961
# 9         SP.ADO.TFRT  YR1961
# 10        SP.ADO.TFRT  YR1962
# 11     SP.DYN.AMRT.FE  YR1962
# 12        SM.POP.NETM  YR1962
# 13     SP.DYN.AMRT.MA  YR1962
# 14  SP.DYN.TO65.FE.ZS  YR1962
#
#                                           Description
# 0          Interpolated using data for 1957 and 1962.
# 1   Interpolated using data for 1957 and 1962, if ...
# 2   Interpolated using data for 1957 and 1962, if ...
# 3          Interpolated using data for 1957 and 1962.
# 4          Interpolated using data for 1957 and 1962.
# 5          Interpolated using data for 1957 and 1962.
# ...

# %%
indicators_un = indicators['IndicatorName'].unique().tolist()
len(indicators_un)
# Out:
# 1344

# %%
indicators_un
# Out:
# ['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#  'Age dependency ratio (% of working-age population)',
#  'Age dependency ratio, old (% of working-age population)',
#  'Age dependency ratio, young (% of working-age population)',
#  'Arms exports (SIPRI trend indicator values)',
#  'Arms imports (SIPRI trend indicator values)',
#  'Birth rate, crude (per 1,000 people)',
#  'CO2 emissions (kt)',
#  'CO2 emissions (metric tons per capita)',
#  'CO2 emissions from gaseous fuel consumption (% of total)',
#  'CO2 emissions from liquid fuel consumption (% of total)',
#  'CO2 emissions from liquid fuel consumption (kt)',
#  'CO2 emissions from solid fuel consumption (% of total)',
#  'Death rate, crude (per 1,000 people)',
#  'Fertility rate, total (births per woman)',
#  'Fixed telephone subscriptions',
#  'Fixed telephone subscriptions (per 100 people)',
#  'Hospital beds (per 1,000 people)',
#  'International migrant stock (% of population)',
# ...

# %%
indicators_migracion = indicators['IndicatorName'].str.contains('migr')
indicators_migracion
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18          True
# 19          True
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 5656428    False
# 5656429    False
# 5656430    False
# 5656431    False
# 5656432    False
# 5656433    False
# 5656434    False
# 5656435    False
# 5656436    False
# 5656437    False
# 5656438    False
# 5656439    False
# 5656440    False
# 5656441    False
# 5656442    False
# 5656443    False
# 5656444    False
# 5656445    False
# 5656446    False
# 5656447    False
# 5656448    False
# ...

# %%
indicators['IndicatorName'].str.find("migr").head()
# Out:
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: IndicatorName, dtype: int64

# %%
indicators2 = indicators[indicators['IndicatorName'] == 'Adolescent fertility rate (births per 1,000 women ages 15-19)']
print(indicators2)
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, IndicatorName, IndicatorCode, Year, Value]
# Index: []

# %%
indicators = pd.read_csv('/Users/riche/Desktop/Data Science/Data Science - Week5-Visualization/Week5-Visualization/world-development-indicators/Indicators.csv', sep=',')
print(type(indicators))
indicators.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
hist_indicator='mig'
hist_country='VEN'

mask1 = indicators['IndicatorName'].str.contains(hist_indicator)
mask2 = indicators['CountryCode'].str.contains(hist_country)

stage = indicators[mask1 & mask2]
stage.head(100)
# Out:
#            CountryName CountryCode  \
# 22721    Venezuela, RB         VEN
# 22722    Venezuela, RB         VEN
# 77714    Venezuela, RB         VEN
# 167298   Venezuela, RB         VEN
# 167299   Venezuela, RB         VEN
# 231432   Venezuela, RB         VEN
# 358809   Venezuela, RB         VEN
# 358810   Venezuela, RB         VEN
# 496730   Venezuela, RB         VEN
# 708673   Venezuela, RB         VEN
# 708674   Venezuela, RB         VEN
# 857822   Venezuela, RB         VEN
# 1090690  Venezuela, RB         VEN
# 1090691  Venezuela, RB         VEN
# 1260082  Venezuela, RB         VEN
# 1518723  Venezuela, RB         VEN
# 1518724  Venezuela, RB         VEN
# 1696112  Venezuela, RB         VEN
# 1994704  Venezuela, RB         VEN
# 1994897  Venezuela, RB         VEN
# 1994898  Venezuela, RB         VEN
# 2232483  Venezuela, RB         VEN
# 2616344  Venezuela, RB         VEN
# 2616345  Venezuela, RB         VEN
# 2887703  Venezuela, RB         VEN
# ...

# %%
hist_series='SM.POP.NETM'
mask_series = series['SeriesCode'].str.contains(hist_series)
series[mask_series]
# Out:
#        SeriesCode                                 Topic  IndicatorName  \
# 1303  SM.POP.NETM  Social Protection & Labor: Migration  Net migration
#
#                                         ShortDefinition  \
# 1303  Net migration is the number of immigrants minu...
#
#                                          LongDefinition UnitOfMeasure  \
# 1303  Net migration is the net total of migrants dur...           NaN
#
#      Periodicity BasePeriod  OtherNotes AggregationMethod  \
# 1303      Annual        NaN         NaN               Sum
#
#                                LimitationsAndExceptions  \
# 1303  International migration is the component of po...
#
#      NotesFromOriginalSource GeneralComments  \
# 1303                     NaN             NaN
#
#                                                  Source  \
# 1303  United Nations Population Division, World Popu...
#
#                        StatisticalConceptAndMethodology  \
# ...

# %%
print(series[mask_series].LongDefinition.all())
# Out:
# Net migration is the net total of migrants during the period, that is, the total number of immigrants less the annual number of emigrants, including both citizens and noncitizens. Data are five-year estimates.

# %%
hist_indicator='Net migration'
hist_country='VEN'

mask1 = indicators['IndicatorName'].str.contains(hist_indicator)
mask2 = indicators['CountryCode'].str.contains(hist_country)

stage = indicators[mask1 & mask2]
stage.head(100)
# Out:
#            CountryName CountryCode  IndicatorName IndicatorCode  Year    Value
# 77714    Venezuela, RB         VEN  Net migration   SM.POP.NETM  1962  18874.0
# 231432   Venezuela, RB         VEN  Net migration   SM.POP.NETM  1967   3172.0
# 496730   Venezuela, RB         VEN  Net migration   SM.POP.NETM  1972    892.0
# 857822   Venezuela, RB         VEN  Net migration   SM.POP.NETM  1977   1094.0
# 1260082  Venezuela, RB         VEN  Net migration   SM.POP.NETM  1982   1373.0
# 1696112  Venezuela, RB         VEN  Net migration   SM.POP.NETM  1987    891.0
# 2232483  Venezuela, RB         VEN  Net migration   SM.POP.NETM  1992   -572.0
# 2887703  Venezuela, RB         VEN  Net migration   SM.POP.NETM  1997  -2061.0
# 3627338  Venezuela, RB         VEN  Net migration   SM.POP.NETM  2002  -7648.0
# 4476421  Venezuela, RB         VEN  Net migration   SM.POP.NETM  2007 -28395.0
# 5373192  Venezuela, RB         VEN  Net migration   SM.POP.NETM  2012 -69121.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8), dpi=80)

plt.ylabel('Net migration')
plt.xlabel('Year')

X = stage['Year']
Y = stage['Value']

plt.scatter(X,Y)
plt.plot(X,Y)

plt.show()

# %%
hist_indicator='Net migration'
hist_country_LA='LCN'
hist_country_name_LA='Latin'

mask1_LA = indicators['IndicatorName'].str.contains(hist_indicator)
mask2_LA = indicators['CountryCode'].str.contains(hist_country_LA)
mask3_LA = indicators['CountryName'].str.contains(hist_country_name_LA)

stage_LA = indicators[mask1_LA & mask2_LA]
stage_LA.head(100)
# Out:
#                                            CountryName CountryCode  \
# 51648    Latin America & Caribbean (all income levels)         LCN
# 201350   Latin America & Caribbean (all income levels)         LCN
# 432263   Latin America & Caribbean (all income levels)         LCN
# 787948   Latin America & Caribbean (all income levels)         LCN
# 1181298  Latin America & Caribbean (all income levels)         LCN
# 1613382  Latin America & Caribbean (all income levels)         LCN
# 2120411  Latin America & Caribbean (all income levels)         LCN
# 2762289  Latin America & Caribbean (all income levels)         LCN
# 3484062  Latin America & Caribbean (all income levels)         LCN
# 4309501  Latin America & Caribbean (all income levels)         LCN
# 5211246  Latin America & Caribbean (all income levels)         LCN
#
#          IndicatorName IndicatorCode  Year      Value
# 51648    Net migration   SM.POP.NETM  1962 -1400307.0
# ...

# %%
plt.figure(figsize=(12, 8), dpi=80)

plt.ylabel('Net migration')
plt.xlabel('Year')

X = stage['Year']
Y = stage['Value']

X1 = stage_LA['Year']
Y1 = stage_LA['Value']/46

plt.plot(X,Y,'o-',label='Venezuela')

plt.plot(X1,Y1,'o-',label='Latin America and the Caribbean (average of the 46 countrys)')

plt.title('Net Migration')

plt.legend()

plt.show()

# %%
is_LCN = country['CountryCode'].str.contains('LCN')
country[is_LCN]
# Out:
#     CountryCode                                      ShortName  \
# 118         LCN  Latin America & Caribbean (all income levels)
#
#                                          TableName  \
# 118  Latin America & Caribbean (all income levels)
#
#                                           LongName Alpha2Code CurrencyUnit  \
# 118  Latin America & Caribbean (all income levels)         ZJ          NaN
#
#                                           SpecialNotes Region IncomeGroup  \
# 118  Latin America and Caribbean regional aggregate...    NaN         NaN
#
#     Wb2Code            ...            GovernmentAccountingConcept  \
# 118      ZJ            ...                                    NaN
#
#     ImfDataDisseminationStandard LatestPopulationCensus LatestHouseholdSurvey  \
# 118                          NaN                    NaN                   NaN
#
#     SourceOfMostRecentIncomeAndExpenditureData VitalRegistrationComplete  \
# ...

# %%
country[is_LCN].SpecialNotes.all()
# Out:
# 'Latin America and Caribbean regional aggregate (including high-income economies).'
